# %% [markdown]
# ## 1

# %%
import numpy as np
import random

genome_length = 50000
read_count = 50000
mean_read_length = 250
std_dev_read_length = 30
max_error_rate = 80
num_readings = 100

genome = ''.join(random.choices('ATGC', k=genome_length))

# %%
def generate_reads(genome, read_count, mean_length, std_dev_length):
    """генерирует риды"""
    reads = []
    positions = []
    genome_length = len(genome)
    
    for _ in range(read_count):
        read_length = int(np.random.normal(mean_length, std_dev_length))
        read_length = max(1, min(genome_length, read_length))
        
        start_pos = random.randint(0, genome_length - read_length)
        read = genome[start_pos:start_pos + read_length]
        reads.append(read)
        positions.append(start_pos)
    
    return reads, positions

def simulate_sequencing(read, num_readings, max_error_rate):
    """имитирует ошибку при секвенировании"""
    sequenced_read = ""
    correct_reads, error_probability = [], []
    error_count = random.randint(0, max_error_rate)
    
    for i, base in enumerate(read):
        # ошибка в N ридах из 100
        illumina_reads = {"A": 0, "T": 0, "G": 0, "C": 0}
        illumina_reads[base] = 100 - error_count 
        
        for _ in range(error_count):
            if base == "A":
                new_base = random.choice("TGC")
            elif base == "T":
                new_base = random.choice("AGC")
            elif base == "G":
                new_base = random.choice("ATC")
            elif base == "C":
                new_base = random.choice("ATG")
                
            illumina_reads[new_base] += 1
        
        freq_base = max(illumina_reads, key=illumina_reads.get)
        sequenced_read += freq_base
        
        error_probability.append(illumina_reads[freq_base]/100)
        # print(f"read {i} P = {1 - illumina_reads[freq_base]/100}")

        if (freq_base != base):
            correct_reads.append((i, base))

    return sequenced_read, correct_reads, error_probability

# %%
true_reads, positions = generate_reads(genome, read_count, mean_read_length, std_dev_read_length)

# %%
import math

fastq_data = []
error_data = []

for read_id, read in enumerate(true_reads):
    sequenced_read, mismatched_bases, error_probability = simulate_sequencing(read, num_readings, max_error_rate)
    # https://en.wikipedia.org/wiki/FASTQ_format
    # https://en.wikipedia.org/wiki/Phred_quality_score
    quality_scores = ["~"]*len(read)
    for pos in range(len(read)):
        if error_probability[pos] == 0:
            continue
        quality_scores[pos] = chr(int(-10 * math.log10(error_probability[pos])) + 33)
    
    fastq_entry = f"@read_{read_id}\n{sequenced_read}\n+\n{"".join(quality_scores)}\n"
    fastq_data.append(fastq_entry)

    # сепаратор в файле ошибок - пробел
    error_data_entry = f"Read_ID: {read_id} Start_Pos: {positions[read_id]} Read_Length: {len(read)} Errors: " + ' '.join([f"Pos: {pos} True_Base: {base}" for pos, base in mismatched_bases]) + "\n"
    error_data.append(error_data_entry)

with open("simulated_reads.fastq", "w") as f:
    f.writelines(fastq_data)

with open("error_positions.dat", "w") as f:
    f.writelines(error_data)

# %% [markdown]
# Чтобы получить более корректно работающую модель, упростил код
#
# Но, тем не менее, какого-то существенного разброса это не дало. Качество прочтений стабильно низкое

# %% [markdown]
# ## 2

# %%
# %%bash
# fastqc ./simulated_reads.fastq
# Out:
# Started analysis of simulated_reads.fastq
# Approx 5% complete for simulated_reads.fastq
# Approx 10% complete for simulated_reads.fastq
# Approx 15% complete for simulated_reads.fastq
# Approx 20% complete for simulated_reads.fastq
# Approx 25% complete for simulated_reads.fastq
# Approx 30% complete for simulated_reads.fastq
# Approx 35% complete for simulated_reads.fastq
# Approx 40% complete for simulated_reads.fastq
# Approx 45% complete for simulated_reads.fastq
# Approx 50% complete for simulated_reads.fastq
# Approx 55% complete for simulated_reads.fastq
# Approx 60% complete for simulated_reads.fastq
# Approx 65% complete for simulated_reads.fastq
# Approx 70% complete for simulated_reads.fastq
# Approx 75% complete for simulated_reads.fastq
# Approx 80% complete for simulated_reads.fastq
# Approx 85% complete for simulated_reads.fastq
# Approx 90% complete for simulated_reads.fastq
# Approx 95% complete for simulated_reads.fastq
# Approx 100% complete for simulated_reads.fastq
# Analysis complete for simulated_reads.fastq

# %% [markdown]
# File simulated_reads_fastqc.html

# %% [markdown]
#           Step options:
#
#                ILLUMINACLIP:<fastaWithAdaptersEtc>:<seed mismatches>:<palindrome clip threshold>:<simple clip threshold>
#                    fastaWithAdaptersEtc: specifies the path to a fasta file containing all the adapters, PCR sequences etc.
#                    The naming of the various sequences within this file determines how they are used. See below.
#                    seedMismatches: specifies the maximum mismatch count which will still allow a full match to be performed
#                    palindromeClipThreshold: specifies how accurate the match between the two ´adapter ligated´ reads must be for PE palindrome read alignment.
#                    simpleClipThreshold: specifies how accurate the match between any adapter etc. sequence must be against a read.
#                    .
#                    The adapters are installed on the Debian system at /usr/share/trimmomatic/.
#
#                SLIDINGWINDOW:<windowSize>:<requiredQuality>
#                    windowSize: specifies the number of bases to average across
#                    requiredQuality: specifies the average quality required.
#
#                LEADING:<quality>
#                    quality: Specifies the minimum quality required to keep a base.
#
#                TRAILING:<quality>
#                    quality: Specifies the minimum quality required to keep a base.
#
#                CROP:<length>
#                    length: The number of bases to keep, from the start of the read.
#
#                HEADCROP:<length>
#                    length: The number of bases to remove from the start of the read.
#
#                MINLENGTH:<length>
#                    length: Specifies the minimum length of reads to be kept.
#
#            Trimming Order
#
#            Trimming  occurs in the order which the steps are specified on the command line. It is recommended in most cases
#            that adapter clipping, if required, is done as early as possible.

# %%
# %%bash
# java -jar ./Trimmomatic-0.39/trimmomatic-0.39.jar SE  ./simulated_reads.fastq trimmomatic.fastq ILLUMINACLIP:TruSeq3-SE:2:30:10 LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36 -phred33 -threads 8
# Out:
# TrimmomaticSE: Started with arguments:
#  ./simulated_reads.fastq trimmomatic.fastq ILLUMINACLIP:TruSeq3-SE:2:30:10 LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36 -phred33 -threads 8
# java.io.FileNotFoundException: /Data/BioinformaticsCourse2024/homework/2_1/TruSeq3-SE (Нет такого файла или каталога)
# 	at java.base/java.io.FileInputStream.open0(Native Method)
# 	at java.base/java.io.FileInputStream.open(FileInputStream.java:216)
# 	at java.base/java.io.FileInputStream.<init>(FileInputStream.java:157)
# 	at org.usadellab.trimmomatic.fasta.FastaParser.parse(FastaParser.java:54)
# 	at org.usadellab.trimmomatic.trim.IlluminaClippingTrimmer.loadSequences(IlluminaClippingTrimmer.java:110)
# 	at org.usadellab.trimmomatic.trim.IlluminaClippingTrimmer.makeIlluminaClippingTrimmer(IlluminaClippingTrimmer.java:71)
# 	at org.usadellab.trimmomatic.trim.TrimmerFactory.makeTrimmer(TrimmerFactory.java:32)
# 	at org.usadellab.trimmomatic.Trimmomatic.createTrimmers(Trimmomatic.java:59)
# 	at org.usadellab.trimmomatic.TrimmomaticSE.run(TrimmomaticSE.java:318)
# 	at org.usadellab.trimmomatic.Trimmomatic.main(Trimmomatic.java:85)
# Input Reads: 50000 Surviving: 0 (0,00%) Dropped: 50000 (100,00%)
# TrimmomaticSE: Completed successfully

# %%
# Сравнение с учетом того, какой получилась симуляция

# %%
from Bio import SeqIO

error_positions = []
with open("error_positions.dat", "r") as f:
    for line in f:
        data = line.split(" ")
        fields = len(data)
        if fields == 7:
            error_positions.append({ "start_pos": int(data[1]), "lenght": int(data[3]), "errors": 0 })
        else:
            ## f"Read_ID: {read_id} Start_Pos: {positions[read_id]} Read_Length: {len(read)} Errors: " + ' '.join([f"Pos: {pos} True_Base: {base}" for pos, base in errors])
            error_positions.append({ "start_pos": int(data[1]), "lenght": int(data[3]), "errors": (fields-7)//2, "error_pos": list(map(int, data[8::4])), "true_base": data[9:4]} )
            # print(data)


def read_fastq(file):
    reads = []
    for record in SeqIO.parse(file, "fastq"):
        reads.append({"id": record.id, "seq": record.seq})
    return reads

def check_match_reads(file1, file2):
    """сравнивает fastq файлы"""
    
    reads1 = read_fastq(file1)
    reads2 = read_fastq(file2)
    all_equal = True
    corrected_count = 0
    
    for read1, read2 in zip(reads1, reads2):
        seq1 = read1["seq"]
        seq2 = read2["seq"]
        
        if (seq1 != seq2):
            all_equal = False
            id = int(read1["id"].split("_", 1)[1])
            true_seq = seq1
            for pos, base in zip(error_positions[id]["error_pos"], error_positions[id]["true_base"]):
                true_seq = true_seq[:pos] + base + true_seq[pos+1:]
            print(f"{read1["id"]} was corrected\tErrors: {sum(1 for a,b in zip(true_seq, seq2) if a != b)}")
            corrected_count += 1
            
    if all_equal:
        print(f"All reads in {file1} and {file2} are match")
    
    return corrected_count

# %%
trimm_count = check_match_reads("simulated_reads.fastq", "trimmomatic.fastq")
# Out:
# All reads in simulated_reads.fastq and trimmomatic.fastq are match

# %%
print(f"{trimm_count}/50.000 was corrected\nMatch rate is {round(100*trimm_count/50000, 3)}%")
# Out:
# 0/50.000 was corrected
# Match rate is 0.0%

# %% [markdown]
# По сравнению с сгенерированным fastq файлом никаких изменений trimmomatic не внес. Все ошибки остались

# %% [markdown]
# ## 3
# https://www.csd.uwo.ca/~ilie/RACER/

# %%
# %%bash
# ./racer/RACER ./simulated_reads.fastq racer.fastq 50000
# Out:
# reading input file...done reading input file
# Genome length = 50000
# Coverage = 249
# Maximum read length = 372
# Number of reads = 50000
# Number of threads = 8
# correcting reads...done correcting reads
# writing back the reads...done
# Total time building witnesses and counters = 2 seconds.
# Total time correcting = 1 seconds.
# Total time = 5 seconds.
# Peak Memory = 87 MB.

# %%
racer_count = check_match_reads("simulated_reads.fastq", "racer.fastq")
# Out:
# read_3 was corrected	Errors: 2
# read_21 was corrected	Errors: 8
# read_23 was corrected	Errors: 2
# read_29 was corrected	Errors: 1
# read_43 was corrected	Errors: 20
# read_47 was corrected	Errors: 3
# read_52 was corrected	Errors: 4
# read_75 was corrected	Errors: 5
# read_87 was corrected	Errors: 10
# read_108 was corrected	Errors: 2
# read_200 was corrected	Errors: 5
# read_201 was corrected	Errors: 4
# read_210 was corrected	Errors: 30
# read_218 was corrected	Errors: 21
# read_268 was corrected	Errors: 14
# read_292 was corrected	Errors: 3
# read_302 was corrected	Errors: 1
# read_309 was corrected	Errors: 2
# read_338 was corrected	Errors: 2
# read_357 was corrected	Errors: 5
# read_381 was corrected	Errors: 4
# read_414 was corrected	Errors: 1
# read_418 was corrected	Errors: 1
# read_428 was corrected	Errors: 1
# read_460 was corrected	Errors: 2
# read_482 was corrected	Errors: 3
# read_483 was corrected	Errors: 3
# read_537 was corrected	Errors: 11
# read_544 was corrected	Errors: 5
# read_549 was corrected	Errors: 20
# read_556 was corrected	Errors: 11
# read_563 was corrected	Errors: 8
# read_590 was corrected	Errors: 23
# read_594 was corrected	Errors: 10
# read_596 was corrected	Errors: 25
# read_620 was corrected	Errors: 1
# read_648 was corrected	Errors: 1
# read_649 was corrected	Errors: 16
# read_652 was corrected	Errors: 15
# read_686 was corrected	Errors: 22
# read_710 was corrected	Errors: 5
# read_731 was corrected	Errors: 2
# read_738 was corrected	Errors: 1
# read_742 was corrected	Errors: 1
# read_744 was corrected	Errors: 1
# read_752 was corrected	Errors: 3
# read_755 was corrected	Errors: 28
# read_765 was corrected	Errors: 8
# read_796 was corrected	Errors: 23
# read_821 was corrected	Errors: 2
# read_829 was corrected	Errors: 17
# read_840 was corrected	Errors: 1
# read_851 was corrected	Errors: 1
# read_858 was corrected	Errors: 1
# read_877 was corrected	Errors: 20
# read_889 was corrected	Errors: 2
# read_943 was corrected	Errors: 12
# read_980 was corrected	Errors: 1
# read_1026 was corrected	Errors: 20
# read_1099 was corrected	Errors: 16
# read_1106 was corrected	Errors: 6
# read_1111 was corrected	Errors: 15
# read_1139 was corrected	Errors: 1
# read_1148 was corrected	Errors: 9
# read_1157 was corrected	Errors: 1
# read_1171 was corrected	Errors: 1
# read_1208 was corrected	Errors: 24
# read_1224 was corrected	Errors: 10
# read_1244 was corrected	Errors: 17
# read_1260 was corrected	Errors: 2
# read_1290 was corrected	Errors: 17
# read_1292 was corrected	Errors: 1
# read_1294 was corrected	Errors: 2
# read_1303 was corrected	Errors: 12
# read_1326 was corrected	Errors: 2
# read_1335 was corrected	Errors: 4
# read_1336 was corrected	Errors: 1
# read_1347 was corrected	Errors: 36
# read_1398 was corrected	Errors: 5
# read_1424 was corrected	Errors: 2
# read_1441 was corrected	Errors: 35
# read_1453 was corrected	Errors: 2
# read_1455 was corrected	Errors: 5
# read_1472 was corrected	Errors: 3
# read_1489 was corrected	Errors: 26
# read_1496 was corrected	Errors: 1
# read_1503 was corrected	Errors: 22
# read_1507 was corrected	Errors: 1
# read_1512 was corrected	Errors: 2
# read_1516 was corrected	Errors: 14
# read_1530 was corrected	Errors: 11
# read_1544 was corrected	Errors: 44
# read_1606 was corrected	Errors: 1
# read_1613 was corrected	Errors: 6
# read_1625 was corrected	Errors: 25
# read_1667 was corrected	Errors: 10
# read_1680 was corrected	Errors: 12
# read_1699 was corrected	Errors: 27
# read_1722 was corrected	Errors: 1
# read_1837 was corrected	Errors: 10
# read_1847 was corrected	Errors: 14
# read_1851 was corrected	Errors: 3
# read_1869 was corrected	Errors: 1
# read_1878 was corrected	Errors: 19
# read_1923 was corrected	Errors: 5
# read_1953 was corrected	Errors: 8
# read_1994 was corrected	Errors: 2
# read_2027 was corrected	Errors: 1
# read_2037 was corrected	Errors: 1
# read_2045 was corrected	Errors: 1
# read_2076 was corrected	Errors: 64
# read_2079 was corrected	Errors: 4
# read_2085 was corrected	Errors: 17
# read_2092 was corrected	Errors: 5
# read_2097 was corrected	Errors: 1
# read_2110 was corrected	Errors: 3
# read_2111 was corrected	Errors: 3
# read_2143 was corrected	Errors: 36
# read_2146 was corrected	Errors: 8
# read_2151 was corrected	Errors: 1
# read_2152 was corrected	Errors: 1
# read_2155 was corrected	Errors: 2
# read_2174 was corrected	Errors: 22
# read_2179 was corrected	Errors: 3
# read_2180 was corrected	Errors: 10
# read_2214 was corrected	Errors: 2
# read_2225 was corrected	Errors: 31
# read_2239 was corrected	Errors: 2
# read_2263 was corrected	Errors: 1
# read_2286 was corrected	Errors: 7
# read_2292 was corrected	Errors: 1
# read_2297 was corrected	Errors: 1
# read_2318 was corrected	Errors: 2
# read_2321 was corrected	Errors: 2
# read_2363 was corrected	Errors: 14
# read_2380 was corrected	Errors: 1
# read_2383 was corrected	Errors: 4
# read_2405 was corrected	Errors: 11
# read_2411 was corrected	Errors: 9
# read_2442 was corrected	Errors: 17
# read_2443 was corrected	Errors: 1
# read_2469 was corrected	Errors: 29
# read_2470 was corrected	Errors: 3
# read_2480 was corrected	Errors: 13
# read_2493 was corrected	Errors: 18
# read_2512 was corrected	Errors: 8
# read_2537 was corrected	Errors: 6
# read_2547 was corrected	Errors: 6
# read_2592 was corrected	Errors: 2
# read_2619 was corrected	Errors: 11
# read_2636 was corrected	Errors: 7
# read_2668 was corrected	Errors: 1
# read_2670 was corrected	Errors: 2
# read_2745 was corrected	Errors: 2
# read_2748 was corrected	Errors: 8
# read_2752 was corrected	Errors: 16
# read_2775 was corrected	Errors: 3
# read_2780 was corrected	Errors: 2
# read_2799 was corrected	Errors: 2
# read_2802 was corrected	Errors: 1
# read_2804 was corrected	Errors: 3
# read_2815 was corrected	Errors: 11
# read_2820 was corrected	Errors: 1
# read_2822 was corrected	Errors: 34
# read_2840 was corrected	Errors: 1
# read_2891 was corrected	Errors: 3
# read_2895 was corrected	Errors: 1
# read_2911 was corrected	Errors: 2
# read_2925 was corrected	Errors: 3
# read_2962 was corrected	Errors: 18
# read_2968 was corrected	Errors: 1
# read_2979 was corrected	Errors: 15
# read_2995 was corrected	Errors: 1
# read_3050 was corrected	Errors: 3
# read_3054 was corrected	Errors: 1
# read_3070 was corrected	Errors: 1
# read_3090 was corrected	Errors: 3
# read_3113 was corrected	Errors: 10
# read_3131 was corrected	Errors: 3
# read_3149 was corrected	Errors: 19
# read_3155 was corrected	Errors: 1
# read_3163 was corrected	Errors: 31
# read_3165 was corrected	Errors: 2
# read_3219 was corrected	Errors: 7
# read_3229 was corrected	Errors: 3
# read_3255 was corrected	Errors: 24
# read_3265 was corrected	Errors: 17
# read_3283 was corrected	Errors: 3
# read_3300 was corrected	Errors: 17
# read_3338 was corrected	Errors: 27
# read_3344 was corrected	Errors: 49
# read_3349 was corrected	Errors: 13
# read_3362 was corrected	Errors: 16
# read_3364 was corrected	Errors: 7
# read_3367 was corrected	Errors: 45
# read_3396 was corrected	Errors: 3
# read_3452 was corrected	Errors: 11
# read_3474 was corrected	Errors: 2
# read_3481 was corrected	Errors: 7
# read_3489 was corrected	Errors: 23
# read_3509 was corrected	Errors: 1
# read_3510 was corrected	Errors: 14
# read_3526 was corrected	Errors: 5
# read_3543 was corrected	Errors: 6
# read_3549 was corrected	Errors: 8
# read_3561 was corrected	Errors: 17
# read_3592 was corrected	Errors: 6
# read_3601 was corrected	Errors: 9
# read_3632 was corrected	Errors: 14
# read_3642 was corrected	Errors: 25
# read_3652 was corrected	Errors: 2
# read_3653 was corrected	Errors: 4
# read_3678 was corrected	Errors: 1
# read_3797 was corrected	Errors: 2
# read_3809 was corrected	Errors: 9
# read_3826 was corrected	Errors: 15
# read_3851 was corrected	Errors: 5
# read_3861 was corrected	Errors: 4
# read_3868 was corrected	Errors: 7
# read_3885 was corrected	Errors: 6
# read_3902 was corrected	Errors: 12
# read_3929 was corrected	Errors: 1
# read_3932 was corrected	Errors: 4
# read_4056 was corrected	Errors: 10
# read_4058 was corrected	Errors: 28
# read_4105 was corrected	Errors: 1
# read_4147 was corrected	Errors: 1
# read_4167 was corrected	Errors: 15
# read_4168 was corrected	Errors: 2
# read_4170 was corrected	Errors: 9
# read_4186 was corrected	Errors: 1
# read_4205 was corrected	Errors: 2
# read_4219 was corrected	Errors: 19
# read_4236 was corrected	Errors: 11
# read_4281 was corrected	Errors: 26
# read_4284 was corrected	Errors: 3
# read_4312 was corrected	Errors: 2
# read_4326 was corrected	Errors: 24
# read_4350 was corrected	Errors: 2
# read_4360 was corrected	Errors: 16
# read_4361 was corrected	Errors: 1
# read_4379 was corrected	Errors: 1
# read_4410 was corrected	Errors: 3
# read_4430 was corrected	Errors: 39
# read_4448 was corrected	Errors: 18
# read_4484 was corrected	Errors: 27
# read_4487 was corrected	Errors: 5
# read_4499 was corrected	Errors: 7
# read_4502 was corrected	Errors: 21
# read_4540 was corrected	Errors: 13
# read_4560 was corrected	Errors: 21
# read_4564 was corrected	Errors: 22
# read_4591 was corrected	Errors: 1
# read_4602 was corrected	Errors: 1
# read_4618 was corrected	Errors: 1
# read_4662 was corrected	Errors: 8
# read_4676 was corrected	Errors: 1
# read_4708 was corrected	Errors: 1
# read_4711 was corrected	Errors: 4
# read_4742 was corrected	Errors: 4
# read_4763 was corrected	Errors: 12
# read_4777 was corrected	Errors: 10
# read_4788 was corrected	Errors: 1
# read_4793 was corrected	Errors: 9
# read_4809 was corrected	Errors: 7
# read_4841 was corrected	Errors: 22
# read_4887 was corrected	Errors: 1
# read_4911 was corrected	Errors: 3
# read_4934 was corrected	Errors: 29
# read_4968 was corrected	Errors: 4
# read_4985 was corrected	Errors: 3
# read_5000 was corrected	Errors: 32
# read_5005 was corrected	Errors: 20
# read_5028 was corrected	Errors: 38
# read_5032 was corrected	Errors: 6
# read_5040 was corrected	Errors: 10
# read_5065 was corrected	Errors: 4
# read_5091 was corrected	Errors: 14
# read_5102 was corrected	Errors: 2
# read_5126 was corrected	Errors: 14
# read_5135 was corrected	Errors: 1
# read_5169 was corrected	Errors: 1
# read_5183 was corrected	Errors: 15
# read_5192 was corrected	Errors: 5
# read_5199 was corrected	Errors: 14
# read_5209 was corrected	Errors: 17
# read_5211 was corrected	Errors: 9
# read_5218 was corrected	Errors: 1
# read_5275 was corrected	Errors: 5
# read_5279 was corrected	Errors: 1
# read_5288 was corrected	Errors: 1
# read_5300 was corrected	Errors: 18
# read_5309 was corrected	Errors: 13
# read_5311 was corrected	Errors: 4
# read_5314 was corrected	Errors: 22
# read_5344 was corrected	Errors: 31
# read_5358 was corrected	Errors: 16
# read_5377 was corrected	Errors: 1
# read_5399 was corrected	Errors: 24
# read_5402 was corrected	Errors: 7
# read_5416 was corrected	Errors: 22
# read_5453 was corrected	Errors: 47
# read_5474 was corrected	Errors: 10
# read_5492 was corrected	Errors: 42
# read_5521 was corrected	Errors: 1
# read_5538 was corrected	Errors: 27
# read_5561 was corrected	Errors: 13
# read_5563 was corrected	Errors: 8
# read_5577 was corrected	Errors: 10
# read_5585 was corrected	Errors: 37
# read_5597 was corrected	Errors: 11
# read_5614 was corrected	Errors: 37
# read_5638 was corrected	Errors: 12
# read_5655 was corrected	Errors: 2
# read_5684 was corrected	Errors: 10
# read_5697 was corrected	Errors: 1
# read_5698 was corrected	Errors: 18
# read_5709 was corrected	Errors: 15
# read_5826 was corrected	Errors: 8
# read_5871 was corrected	Errors: 3
# read_5877 was corrected	Errors: 4
# read_5916 was corrected	Errors: 11
# read_5919 was corrected	Errors: 1
# read_5939 was corrected	Errors: 19
# read_5956 was corrected	Errors: 7
# read_5961 was corrected	Errors: 3
# read_5971 was corrected	Errors: 1
# read_5997 was corrected	Errors: 5
# read_6002 was corrected	Errors: 9
# read_6015 was corrected	Errors: 9
# read_6018 was corrected	Errors: 2
# read_6077 was corrected	Errors: 1
# read_6099 was corrected	Errors: 12
# read_6142 was corrected	Errors: 18
# read_6144 was corrected	Errors: 4
# read_6148 was corrected	Errors: 22
# read_6156 was corrected	Errors: 2
# read_6242 was corrected	Errors: 14
# read_6260 was corrected	Errors: 4
# read_6308 was corrected	Errors: 22
# read_6321 was corrected	Errors: 2
# read_6340 was corrected	Errors: 2
# read_6368 was corrected	Errors: 8
# read_6370 was corrected	Errors: 5
# read_6386 was corrected	Errors: 22
# read_6411 was corrected	Errors: 20
# read_6431 was corrected	Errors: 9
# read_6479 was corrected	Errors: 5
# read_6487 was corrected	Errors: 29
# read_6488 was corrected	Errors: 37
# read_6492 was corrected	Errors: 5
# read_6498 was corrected	Errors: 2
# read_6501 was corrected	Errors: 4
# read_6515 was corrected	Errors: 1
# read_6534 was corrected	Errors: 2
# read_6551 was corrected	Errors: 17
# read_6570 was corrected	Errors: 11
# read_6579 was corrected	Errors: 4
# read_6592 was corrected	Errors: 17
# read_6600 was corrected	Errors: 23
# read_6647 was corrected	Errors: 3
# read_6654 was corrected	Errors: 5
# read_6669 was corrected	Errors: 2
# read_6685 was corrected	Errors: 1
# read_6712 was corrected	Errors: 7
# read_6715 was corrected	Errors: 6
# read_6718 was corrected	Errors: 5
# read_6729 was corrected	Errors: 2
# read_6734 was corrected	Errors: 17
# read_6743 was corrected	Errors: 46
# read_6755 was corrected	Errors: 8
# read_6782 was corrected	Errors: 2
# read_6809 was corrected	Errors: 11
# read_6825 was corrected	Errors: 35
# read_6830 was corrected	Errors: 9
# read_6833 was corrected	Errors: 1
# read_6869 was corrected	Errors: 1
# read_6872 was corrected	Errors: 6
# read_6902 was corrected	Errors: 8
# read_6911 was corrected	Errors: 3
# read_6947 was corrected	Errors: 1
# read_6979 was corrected	Errors: 3
# read_6985 was corrected	Errors: 14
# read_6987 was corrected	Errors: 7
# read_6993 was corrected	Errors: 18
# read_6998 was corrected	Errors: 16
# read_6999 was corrected	Errors: 8
# read_7000 was corrected	Errors: 18
# read_7004 was corrected	Errors: 5
# read_7021 was corrected	Errors: 2
# read_7026 was corrected	Errors: 4
# read_7033 was corrected	Errors: 30
# read_7066 was corrected	Errors: 18
# read_7069 was corrected	Errors: 10
# read_7075 was corrected	Errors: 1
# read_7094 was corrected	Errors: 1
# read_7123 was corrected	Errors: 18
# read_7127 was corrected	Errors: 12
# read_7128 was corrected	Errors: 6
# read_7177 was corrected	Errors: 9
# read_7186 was corrected	Errors: 1
# read_7217 was corrected	Errors: 6
# read_7230 was corrected	Errors: 7
# read_7236 was corrected	Errors: 14
# read_7266 was corrected	Errors: 7
# read_7272 was corrected	Errors: 27
# read_7277 was corrected	Errors: 6
# read_7281 was corrected	Errors: 3
# read_7326 was corrected	Errors: 2
# read_7342 was corrected	Errors: 3
# read_7347 was corrected	Errors: 15
# read_7348 was corrected	Errors: 3
# read_7361 was corrected	Errors: 3
# read_7368 was corrected	Errors: 26
# read_7386 was corrected	Errors: 30
# read_7387 was corrected	Errors: 26
# read_7401 was corrected	Errors: 1
# read_7417 was corrected	Errors: 4
# read_7430 was corrected	Errors: 18
# read_7445 was corrected	Errors: 15
# read_7468 was corrected	Errors: 8
# read_7521 was corrected	Errors: 6
# read_7532 was corrected	Errors: 1
# read_7554 was corrected	Errors: 6
# read_7557 was corrected	Errors: 9
# read_7568 was corrected	Errors: 35
# read_7575 was corrected	Errors: 1
# read_7582 was corrected	Errors: 18
# read_7586 was corrected	Errors: 4
# read_7605 was corrected	Errors: 1
# read_7621 was corrected	Errors: 1
# read_7628 was corrected	Errors: 1
# read_7641 was corrected	Errors: 28
# read_7667 was corrected	Errors: 21
# read_7680 was corrected	Errors: 21
# read_7683 was corrected	Errors: 1
# read_7694 was corrected	Errors: 17
# read_7700 was corrected	Errors: 10
# read_7729 was corrected	Errors: 6
# read_7731 was corrected	Errors: 1
# read_7784 was corrected	Errors: 7
# read_7795 was corrected	Errors: 1
# read_7814 was corrected	Errors: 13
# read_7827 was corrected	Errors: 2
# read_7831 was corrected	Errors: 5
# read_7841 was corrected	Errors: 1
# read_7867 was corrected	Errors: 1
# read_7899 was corrected	Errors: 2
# read_7900 was corrected	Errors: 1
# read_7932 was corrected	Errors: 1
# read_7945 was corrected	Errors: 18
# read_7946 was corrected	Errors: 4
# read_7964 was corrected	Errors: 8
# read_7991 was corrected	Errors: 1
# read_7995 was corrected	Errors: 15
# read_7999 was corrected	Errors: 8
# read_8000 was corrected	Errors: 20
# read_8029 was corrected	Errors: 3
# read_8082 was corrected	Errors: 1
# read_8137 was corrected	Errors: 20
# read_8138 was corrected	Errors: 1
# read_8162 was corrected	Errors: 3
# read_8174 was corrected	Errors: 2
# read_8188 was corrected	Errors: 20
# read_8200 was corrected	Errors: 20
# read_8219 was corrected	Errors: 19
# read_8231 was corrected	Errors: 22
# read_8301 was corrected	Errors: 11
# read_8317 was corrected	Errors: 2
# read_8326 was corrected	Errors: 14
# read_8349 was corrected	Errors: 3
# read_8355 was corrected	Errors: 4
# read_8368 was corrected	Errors: 1
# read_8370 was corrected	Errors: 14
# read_8424 was corrected	Errors: 1
# read_8436 was corrected	Errors: 4
# read_8440 was corrected	Errors: 2
# read_8442 was corrected	Errors: 1
# read_8447 was corrected	Errors: 1
# read_8456 was corrected	Errors: 6
# read_8481 was corrected	Errors: 18
# read_8497 was corrected	Errors: 5
# read_8498 was corrected	Errors: 1
# read_8547 was corrected	Errors: 25
# read_8563 was corrected	Errors: 11
# read_8566 was corrected	Errors: 2
# read_8577 was corrected	Errors: 19
# read_8586 was corrected	Errors: 7
# read_8605 was corrected	Errors: 25
# read_8607 was corrected	Errors: 4
# read_8608 was corrected	Errors: 4
# read_8613 was corrected	Errors: 2
# read_8639 was corrected	Errors: 10
# read_8643 was corrected	Errors: 3
# read_8650 was corrected	Errors: 1
# read_8665 was corrected	Errors: 2
# read_8667 was corrected	Errors: 18
# read_8682 was corrected	Errors: 3
# read_8756 was corrected	Errors: 5
# read_8787 was corrected	Errors: 3
# read_8817 was corrected	Errors: 18
# read_8871 was corrected	Errors: 3
# read_8883 was corrected	Errors: 15
# read_8887 was corrected	Errors: 5
# read_8890 was corrected	Errors: 2
# read_8899 was corrected	Errors: 21
# read_8905 was corrected	Errors: 1
# read_8960 was corrected	Errors: 1
# read_8983 was corrected	Errors: 3
# read_9008 was corrected	Errors: 27
# read_9014 was corrected	Errors: 10
# read_9058 was corrected	Errors: 7
# read_9073 was corrected	Errors: 14
# read_9097 was corrected	Errors: 33
# read_9128 was corrected	Errors: 4
# read_9134 was corrected	Errors: 5
# read_9158 was corrected	Errors: 2
# read_9159 was corrected	Errors: 7
# read_9177 was corrected	Errors: 18
# read_9195 was corrected	Errors: 2
# read_9207 was corrected	Errors: 3
# read_9217 was corrected	Errors: 14
# read_9224 was corrected	Errors: 2
# read_9233 was corrected	Errors: 2
# read_9245 was corrected	Errors: 6
# read_9255 was corrected	Errors: 29
# read_9330 was corrected	Errors: 3
# read_9333 was corrected	Errors: 21
# read_9342 was corrected	Errors: 13
# read_9387 was corrected	Errors: 36
# read_9407 was corrected	Errors: 1
# read_9417 was corrected	Errors: 1
# read_9420 was corrected	Errors: 1
# read_9427 was corrected	Errors: 9
# read_9470 was corrected	Errors: 37
# read_9478 was corrected	Errors: 20
# read_9483 was corrected	Errors: 1
# read_9489 was corrected	Errors: 2
# read_9527 was corrected	Errors: 1
# read_9530 was corrected	Errors: 2
# read_9539 was corrected	Errors: 1
# read_9542 was corrected	Errors: 3
# read_9547 was corrected	Errors: 9
# read_9562 was corrected	Errors: 7
# read_9602 was corrected	Errors: 4
# read_9614 was corrected	Errors: 36
# read_9615 was corrected	Errors: 7
# read_9627 was corrected	Errors: 2
# read_9643 was corrected	Errors: 7
# read_9673 was corrected	Errors: 4
# read_9698 was corrected	Errors: 6
# read_9755 was corrected	Errors: 1
# read_9758 was corrected	Errors: 11
# read_9760 was corrected	Errors: 7
# read_9773 was corrected	Errors: 20
# read_9783 was corrected	Errors: 22
# read_9810 was corrected	Errors: 1
# read_9815 was corrected	Errors: 3
# read_9829 was corrected	Errors: 7
# read_9853 was corrected	Errors: 17
# read_9903 was corrected	Errors: 5
# read_9917 was corrected	Errors: 1
# read_9925 was corrected	Errors: 13
# read_9927 was corrected	Errors: 9
# read_9942 was corrected	Errors: 8
# read_9945 was corrected	Errors: 3
# read_10000 was corrected	Errors: 3
# read_10012 was corrected	Errors: 7
# read_10024 was corrected	Errors: 6
# read_10028 was corrected	Errors: 4
# read_10054 was corrected	Errors: 16
# read_10064 was corrected	Errors: 9
# read_10069 was corrected	Errors: 1
# read_10153 was corrected	Errors: 23
# read_10162 was corrected	Errors: 3
# read_10194 was corrected	Errors: 2
# read_10210 was corrected	Errors: 6
# read_10229 was corrected	Errors: 11
# read_10247 was corrected	Errors: 8
# read_10255 was corrected	Errors: 5
# read_10256 was corrected	Errors: 2
# read_10266 was corrected	Errors: 17
# read_10267 was corrected	Errors: 1
# read_10289 was corrected	Errors: 1
# read_10290 was corrected	Errors: 3
# read_10291 was corrected	Errors: 1
# read_10297 was corrected	Errors: 31
# read_10311 was corrected	Errors: 6
# read_10312 was corrected	Errors: 1
# read_10343 was corrected	Errors: 36
# read_10359 was corrected	Errors: 1
# read_10369 was corrected	Errors: 28
# read_10398 was corrected	Errors: 1
# read_10400 was corrected	Errors: 2
# read_10429 was corrected	Errors: 5
# read_10431 was corrected	Errors: 2
# read_10448 was corrected	Errors: 25
# read_10450 was corrected	Errors: 1
# read_10457 was corrected	Errors: 13
# read_10491 was corrected	Errors: 2
# read_10610 was corrected	Errors: 13
# read_10625 was corrected	Errors: 5
# read_10628 was corrected	Errors: 7
# read_10631 was corrected	Errors: 3
# read_10649 was corrected	Errors: 10
# read_10707 was corrected	Errors: 12
# read_10716 was corrected	Errors: 1
# read_10759 was corrected	Errors: 16
# read_10769 was corrected	Errors: 7
# read_10781 was corrected	Errors: 23
# read_10791 was corrected	Errors: 8
# read_10837 was corrected	Errors: 24
# read_10838 was corrected	Errors: 20
# read_10863 was corrected	Errors: 1
# read_10883 was corrected	Errors: 9
# read_10932 was corrected	Errors: 44
# read_10945 was corrected	Errors: 2
# read_10975 was corrected	Errors: 1
# read_10982 was corrected	Errors: 2
# read_11011 was corrected	Errors: 22
# read_11012 was corrected	Errors: 11
# read_11049 was corrected	Errors: 2
# read_11063 was corrected	Errors: 48
# read_11067 was corrected	Errors: 1
# read_11099 was corrected	Errors: 9
# read_11114 was corrected	Errors: 13
# read_11122 was corrected	Errors: 1
# read_11140 was corrected	Errors: 14
# read_11161 was corrected	Errors: 24
# read_11170 was corrected	Errors: 1
# read_11189 was corrected	Errors: 8
# read_11199 was corrected	Errors: 5
# read_11209 was corrected	Errors: 8
# read_11265 was corrected	Errors: 13
# read_11266 was corrected	Errors: 17
# read_11267 was corrected	Errors: 13
# read_11276 was corrected	Errors: 17
# read_11289 was corrected	Errors: 8
# read_11308 was corrected	Errors: 28
# read_11312 was corrected	Errors: 19
# read_11343 was corrected	Errors: 1
# read_11361 was corrected	Errors: 5
# read_11406 was corrected	Errors: 15
# read_11423 was corrected	Errors: 13
# read_11476 was corrected	Errors: 7
# read_11477 was corrected	Errors: 5
# read_11485 was corrected	Errors: 2
# read_11511 was corrected	Errors: 1
# read_11515 was corrected	Errors: 1
# read_11519 was corrected	Errors: 7
# read_11522 was corrected	Errors: 4
# read_11535 was corrected	Errors: 33
# read_11541 was corrected	Errors: 7
# read_11545 was corrected	Errors: 7
# read_11554 was corrected	Errors: 2
# read_11561 was corrected	Errors: 5
# read_11590 was corrected	Errors: 8
# read_11632 was corrected	Errors: 8
# read_11645 was corrected	Errors: 18
# read_11649 was corrected	Errors: 4
# read_11654 was corrected	Errors: 4
# read_11722 was corrected	Errors: 2
# read_11737 was corrected	Errors: 1
# read_11738 was corrected	Errors: 1
# read_11747 was corrected	Errors: 20
# read_11783 was corrected	Errors: 2
# read_11829 was corrected	Errors: 4
# read_11873 was corrected	Errors: 27
# read_11913 was corrected	Errors: 3
# read_11917 was corrected	Errors: 1
# read_11946 was corrected	Errors: 3
# read_11948 was corrected	Errors: 1
# read_11962 was corrected	Errors: 3
# read_11994 was corrected	Errors: 11
# read_11997 was corrected	Errors: 1
# read_12033 was corrected	Errors: 29
# read_12034 was corrected	Errors: 1
# read_12054 was corrected	Errors: 20
# read_12092 was corrected	Errors: 1
# read_12096 was corrected	Errors: 3
# read_12101 was corrected	Errors: 18
# read_12137 was corrected	Errors: 3
# read_12242 was corrected	Errors: 1
# read_12259 was corrected	Errors: 35
# read_12262 was corrected	Errors: 2
# read_12264 was corrected	Errors: 3
# read_12291 was corrected	Errors: 10
# read_12294 was corrected	Errors: 2
# read_12309 was corrected	Errors: 5
# read_12320 was corrected	Errors: 2
# read_12326 was corrected	Errors: 12
# read_12332 was corrected	Errors: 61
# read_12346 was corrected	Errors: 5
# read_12350 was corrected	Errors: 3
# read_12362 was corrected	Errors: 3
# read_12376 was corrected	Errors: 11
# read_12385 was corrected	Errors: 1
# read_12390 was corrected	Errors: 1
# read_12405 was corrected	Errors: 2
# read_12427 was corrected	Errors: 1
# read_12466 was corrected	Errors: 1
# read_12516 was corrected	Errors: 21
# read_12544 was corrected	Errors: 5
# read_12554 was corrected	Errors: 1
# read_12560 was corrected	Errors: 4
# read_12562 was corrected	Errors: 1
# read_12564 was corrected	Errors: 14
# read_12576 was corrected	Errors: 3
# read_12609 was corrected	Errors: 26
# read_12612 was corrected	Errors: 20
# read_12623 was corrected	Errors: 21
# read_12632 was corrected	Errors: 16
# read_12633 was corrected	Errors: 7
# read_12637 was corrected	Errors: 11
# read_12650 was corrected	Errors: 30
# read_12659 was corrected	Errors: 23
# read_12667 was corrected	Errors: 3
# read_12669 was corrected	Errors: 16
# read_12697 was corrected	Errors: 1
# read_12701 was corrected	Errors: 7
# read_12713 was corrected	Errors: 10
# read_12724 was corrected	Errors: 2
# read_12731 was corrected	Errors: 5
# read_12734 was corrected	Errors: 31
# read_12741 was corrected	Errors: 11
# read_12798 was corrected	Errors: 3
# read_12843 was corrected	Errors: 6
# read_12852 was corrected	Errors: 27
# read_12863 was corrected	Errors: 3
# read_12877 was corrected	Errors: 17
# read_12896 was corrected	Errors: 16
# read_12937 was corrected	Errors: 8
# read_12947 was corrected	Errors: 5
# read_12968 was corrected	Errors: 2
# read_12979 was corrected	Errors: 2
# read_12981 was corrected	Errors: 5
# read_12994 was corrected	Errors: 7
# read_13049 was corrected	Errors: 13
# read_13081 was corrected	Errors: 6
# read_13084 was corrected	Errors: 5
# read_13095 was corrected	Errors: 13
# read_13110 was corrected	Errors: 35
# read_13115 was corrected	Errors: 2
# read_13181 was corrected	Errors: 2
# read_13205 was corrected	Errors: 7
# read_13210 was corrected	Errors: 30
# read_13240 was corrected	Errors: 2
# read_13261 was corrected	Errors: 24
# read_13265 was corrected	Errors: 10
# read_13290 was corrected	Errors: 17
# read_13336 was corrected	Errors: 17
# read_13339 was corrected	Errors: 1
# read_13359 was corrected	Errors: 3
# read_13388 was corrected	Errors: 2
# read_13412 was corrected	Errors: 21
# read_13426 was corrected	Errors: 6
# read_13432 was corrected	Errors: 17
# read_13487 was corrected	Errors: 7
# read_13549 was corrected	Errors: 1
# read_13571 was corrected	Errors: 9
# read_13598 was corrected	Errors: 2
# read_13599 was corrected	Errors: 7
# read_13612 was corrected	Errors: 14
# read_13629 was corrected	Errors: 6
# read_13636 was corrected	Errors: 10
# read_13647 was corrected	Errors: 34
# read_13648 was corrected	Errors: 2
# read_13683 was corrected	Errors: 35
# read_13688 was corrected	Errors: 38
# read_13689 was corrected	Errors: 16
# read_13788 was corrected	Errors: 2
# read_13801 was corrected	Errors: 2
# read_13815 was corrected	Errors: 1
# read_13836 was corrected	Errors: 2
# read_13846 was corrected	Errors: 1
# read_13855 was corrected	Errors: 25
# read_13863 was corrected	Errors: 3
# read_13902 was corrected	Errors: 14
# read_13904 was corrected	Errors: 7
# read_13926 was corrected	Errors: 7
# read_13944 was corrected	Errors: 28
# read_13982 was corrected	Errors: 2
# read_13990 was corrected	Errors: 1
# read_14015 was corrected	Errors: 2
# read_14017 was corrected	Errors: 2
# read_14021 was corrected	Errors: 7
# read_14032 was corrected	Errors: 19
# read_14045 was corrected	Errors: 20
# read_14053 was corrected	Errors: 7
# read_14079 was corrected	Errors: 21
# read_14105 was corrected	Errors: 3
# read_14124 was corrected	Errors: 20
# read_14126 was corrected	Errors: 18
# read_14178 was corrected	Errors: 3
# read_14195 was corrected	Errors: 2
# read_14211 was corrected	Errors: 12
# read_14239 was corrected	Errors: 19
# read_14251 was corrected	Errors: 4
# read_14257 was corrected	Errors: 5
# read_14263 was corrected	Errors: 4
# read_14295 was corrected	Errors: 9
# read_14322 was corrected	Errors: 7
# read_14329 was corrected	Errors: 8
# read_14338 was corrected	Errors: 20
# read_14379 was corrected	Errors: 11
# read_14392 was corrected	Errors: 3
# read_14425 was corrected	Errors: 1
# read_14432 was corrected	Errors: 19
# read_14444 was corrected	Errors: 2
# read_14496 was corrected	Errors: 28
# read_14546 was corrected	Errors: 2
# read_14549 was corrected	Errors: 1
# read_14566 was corrected	Errors: 45
# read_14578 was corrected	Errors: 21
# read_14589 was corrected	Errors: 6
# read_14615 was corrected	Errors: 4
# read_14616 was corrected	Errors: 4
# read_14632 was corrected	Errors: 1
# read_14639 was corrected	Errors: 39
# read_14640 was corrected	Errors: 9
# read_14642 was corrected	Errors: 18
# read_14652 was corrected	Errors: 1
# read_14680 was corrected	Errors: 18
# read_14688 was corrected	Errors: 2
# read_14713 was corrected	Errors: 1
# read_14730 was corrected	Errors: 1
# read_14751 was corrected	Errors: 1
# read_14756 was corrected	Errors: 10
# read_14762 was corrected	Errors: 37
# read_14803 was corrected	Errors: 8
# read_14804 was corrected	Errors: 4
# read_14806 was corrected	Errors: 7
# read_14839 was corrected	Errors: 16
# read_14850 was corrected	Errors: 12
# read_14856 was corrected	Errors: 3
# read_14858 was corrected	Errors: 10
# read_14894 was corrected	Errors: 7
# read_14985 was corrected	Errors: 14
# read_15048 was corrected	Errors: 17
# read_15051 was corrected	Errors: 2
# read_15076 was corrected	Errors: 3
# read_15090 was corrected	Errors: 12
# read_15091 was corrected	Errors: 5
# read_15128 was corrected	Errors: 1
# read_15182 was corrected	Errors: 3
# read_15202 was corrected	Errors: 10
# read_15225 was corrected	Errors: 14
# read_15229 was corrected	Errors: 7
# read_15275 was corrected	Errors: 8
# read_15282 was corrected	Errors: 39
# read_15315 was corrected	Errors: 2
# read_15318 was corrected	Errors: 4
# read_15324 was corrected	Errors: 19
# read_15325 was corrected	Errors: 11
# read_15331 was corrected	Errors: 1
# read_15346 was corrected	Errors: 1
# read_15358 was corrected	Errors: 21
# read_15422 was corrected	Errors: 14
# read_15452 was corrected	Errors: 37
# read_15456 was corrected	Errors: 1
# read_15458 was corrected	Errors: 7
# read_15480 was corrected	Errors: 11
# read_15523 was corrected	Errors: 4
# read_15528 was corrected	Errors: 3
# read_15533 was corrected	Errors: 21
# read_15557 was corrected	Errors: 7
# read_15562 was corrected	Errors: 1
# read_15605 was corrected	Errors: 16
# read_15621 was corrected	Errors: 1
# read_15633 was corrected	Errors: 2
# read_15636 was corrected	Errors: 23
# read_15701 was corrected	Errors: 2
# read_15703 was corrected	Errors: 1
# read_15725 was corrected	Errors: 2
# read_15726 was corrected	Errors: 25
# read_15730 was corrected	Errors: 1
# read_15732 was corrected	Errors: 1
# read_15745 was corrected	Errors: 1
# read_15749 was corrected	Errors: 3
# read_15795 was corrected	Errors: 4
# read_15805 was corrected	Errors: 1
# read_15828 was corrected	Errors: 8
# read_15829 was corrected	Errors: 20
# read_15849 was corrected	Errors: 4
# read_15855 was corrected	Errors: 1
# read_15876 was corrected	Errors: 27
# read_15887 was corrected	Errors: 3
# read_15895 was corrected	Errors: 1
# read_15908 was corrected	Errors: 49
# read_15919 was corrected	Errors: 15
# read_15938 was corrected	Errors: 4
# read_15961 was corrected	Errors: 20
# read_15988 was corrected	Errors: 2
# read_15990 was corrected	Errors: 2
# read_16011 was corrected	Errors: 8
# read_16022 was corrected	Errors: 11
# read_16031 was corrected	Errors: 10
# read_16039 was corrected	Errors: 2
# read_16047 was corrected	Errors: 2
# read_16048 was corrected	Errors: 6
# read_16102 was corrected	Errors: 5
# read_16119 was corrected	Errors: 1
# read_16170 was corrected	Errors: 24
# read_16181 was corrected	Errors: 1
# read_16241 was corrected	Errors: 2
# read_16249 was corrected	Errors: 9
# read_16258 was corrected	Errors: 3
# read_16274 was corrected	Errors: 31
# read_16275 was corrected	Errors: 1
# read_16292 was corrected	Errors: 1
# read_16303 was corrected	Errors: 20
# read_16307 was corrected	Errors: 2
# read_16309 was corrected	Errors: 1
# read_16326 was corrected	Errors: 4
# read_16340 was corrected	Errors: 5
# read_16343 was corrected	Errors: 7
# read_16370 was corrected	Errors: 11
# read_16385 was corrected	Errors: 3
# read_16402 was corrected	Errors: 17
# read_16419 was corrected	Errors: 22
# read_16519 was corrected	Errors: 1
# read_16520 was corrected	Errors: 1
# read_16560 was corrected	Errors: 2
# read_16599 was corrected	Errors: 24
# read_16606 was corrected	Errors: 1
# read_16617 was corrected	Errors: 10
# read_16642 was corrected	Errors: 4
# read_16649 was corrected	Errors: 24
# read_16663 was corrected	Errors: 1
# read_16697 was corrected	Errors: 1
# read_16708 was corrected	Errors: 3
# read_16721 was corrected	Errors: 2
# read_16738 was corrected	Errors: 8
# read_16741 was corrected	Errors: 6
# read_16743 was corrected	Errors: 22
# read_16758 was corrected	Errors: 9
# read_16801 was corrected	Errors: 1
# read_16819 was corrected	Errors: 21
# read_16872 was corrected	Errors: 2
# read_16874 was corrected	Errors: 1
# read_16894 was corrected	Errors: 4
# read_16938 was corrected	Errors: 19
# read_16943 was corrected	Errors: 5
# read_17032 was corrected	Errors: 1
# read_17062 was corrected	Errors: 1
# read_17079 was corrected	Errors: 3
# read_17090 was corrected	Errors: 8
# read_17099 was corrected	Errors: 13
# read_17104 was corrected	Errors: 41
# read_17126 was corrected	Errors: 1
# read_17138 was corrected	Errors: 1
# read_17168 was corrected	Errors: 6
# read_17195 was corrected	Errors: 2
# read_17215 was corrected	Errors: 26
# read_17219 was corrected	Errors: 9
# read_17220 was corrected	Errors: 4
# read_17248 was corrected	Errors: 16
# read_17255 was corrected	Errors: 6
# read_17257 was corrected	Errors: 1
# read_17291 was corrected	Errors: 8
# read_17302 was corrected	Errors: 1
# read_17305 was corrected	Errors: 4
# read_17327 was corrected	Errors: 3
# read_17362 was corrected	Errors: 1
# read_17363 was corrected	Errors: 6
# read_17371 was corrected	Errors: 36
# read_17406 was corrected	Errors: 8
# read_17477 was corrected	Errors: 35
# read_17485 was corrected	Errors: 8
# read_17522 was corrected	Errors: 7
# read_17523 was corrected	Errors: 7
# read_17551 was corrected	Errors: 1
# read_17565 was corrected	Errors: 4
# read_17590 was corrected	Errors: 10
# read_17592 was corrected	Errors: 13
# read_17600 was corrected	Errors: 3
# read_17609 was corrected	Errors: 1
# read_17616 was corrected	Errors: 24
# read_17647 was corrected	Errors: 9
# read_17650 was corrected	Errors: 1
# read_17651 was corrected	Errors: 18
# read_17675 was corrected	Errors: 4
# read_17689 was corrected	Errors: 1
# read_17691 was corrected	Errors: 8
# read_17728 was corrected	Errors: 2
# read_17754 was corrected	Errors: 13
# read_17760 was corrected	Errors: 1
# read_17766 was corrected	Errors: 22
# read_17784 was corrected	Errors: 11
# read_17833 was corrected	Errors: 1
# read_17853 was corrected	Errors: 1
# read_17867 was corrected	Errors: 1
# read_17895 was corrected	Errors: 6
# read_17927 was corrected	Errors: 16
# read_17956 was corrected	Errors: 16
# read_17978 was corrected	Errors: 8
# read_17986 was corrected	Errors: 8
# read_18022 was corrected	Errors: 3
# read_18038 was corrected	Errors: 1
# read_18064 was corrected	Errors: 20
# read_18076 was corrected	Errors: 9
# read_18114 was corrected	Errors: 8
# read_18177 was corrected	Errors: 18
# read_18229 was corrected	Errors: 12
# read_18347 was corrected	Errors: 12
# read_18348 was corrected	Errors: 17
# read_18362 was corrected	Errors: 7
# read_18396 was corrected	Errors: 1
# read_18417 was corrected	Errors: 1
# read_18422 was corrected	Errors: 31
# read_18432 was corrected	Errors: 20
# read_18444 was corrected	Errors: 1
# read_18453 was corrected	Errors: 9
# read_18460 was corrected	Errors: 11
# read_18472 was corrected	Errors: 2
# read_18474 was corrected	Errors: 2
# read_18480 was corrected	Errors: 1
# read_18488 was corrected	Errors: 1
# read_18521 was corrected	Errors: 7
# read_18535 was corrected	Errors: 6
# read_18554 was corrected	Errors: 2
# read_18558 was corrected	Errors: 1
# read_18588 was corrected	Errors: 1
# read_18637 was corrected	Errors: 8
# read_18649 was corrected	Errors: 28
# read_18660 was corrected	Errors: 7
# read_18683 was corrected	Errors: 5
# read_18700 was corrected	Errors: 1
# read_18751 was corrected	Errors: 3
# read_18756 was corrected	Errors: 15
# read_18766 was corrected	Errors: 1
# read_18778 was corrected	Errors: 5
# read_18800 was corrected	Errors: 15
# read_18848 was corrected	Errors: 24
# read_18856 was corrected	Errors: 13
# read_18877 was corrected	Errors: 2
# read_18878 was corrected	Errors: 6
# read_18885 was corrected	Errors: 1
# read_18895 was corrected	Errors: 3
# read_18905 was corrected	Errors: 1
# read_18930 was corrected	Errors: 12
# read_18936 was corrected	Errors: 21
# read_19021 was corrected	Errors: 1
# read_19038 was corrected	Errors: 3
# read_19041 was corrected	Errors: 34
# read_19043 was corrected	Errors: 27
# read_19047 was corrected	Errors: 2
# read_19127 was corrected	Errors: 2
# read_19151 was corrected	Errors: 1
# read_19205 was corrected	Errors: 2
# read_19245 was corrected	Errors: 8
# read_19249 was corrected	Errors: 20
# read_19294 was corrected	Errors: 6
# read_19301 was corrected	Errors: 10
# read_19308 was corrected	Errors: 5
# read_19319 was corrected	Errors: 5
# read_19326 was corrected	Errors: 30
# read_19330 was corrected	Errors: 23
# read_19359 was corrected	Errors: 13
# read_19377 was corrected	Errors: 3
# read_19380 was corrected	Errors: 1
# read_19389 was corrected	Errors: 22
# read_19392 was corrected	Errors: 34
# read_19408 was corrected	Errors: 18
# read_19411 was corrected	Errors: 21
# read_19416 was corrected	Errors: 10
# read_19452 was corrected	Errors: 8
# read_19455 was corrected	Errors: 1
# read_19469 was corrected	Errors: 3
# read_19512 was corrected	Errors: 7
# read_19546 was corrected	Errors: 3
# read_19587 was corrected	Errors: 6
# read_19601 was corrected	Errors: 9
# read_19626 was corrected	Errors: 5
# read_19691 was corrected	Errors: 12
# read_19698 was corrected	Errors: 8
# read_19704 was corrected	Errors: 14
# read_19743 was corrected	Errors: 6
# read_19748 was corrected	Errors: 21
# read_19758 was corrected	Errors: 20
# read_19790 was corrected	Errors: 2
# read_19800 was corrected	Errors: 10
# read_19801 was corrected	Errors: 2
# read_19806 was corrected	Errors: 4
# read_19817 was corrected	Errors: 2
# read_19861 was corrected	Errors: 15
# read_19873 was corrected	Errors: 2
# read_19901 was corrected	Errors: 21
# read_19904 was corrected	Errors: 3
# read_19972 was corrected	Errors: 2
# read_20025 was corrected	Errors: 7
# read_20038 was corrected	Errors: 12
# read_20042 was corrected	Errors: 8
# read_20043 was corrected	Errors: 2
# read_20050 was corrected	Errors: 9
# read_20063 was corrected	Errors: 3
# read_20075 was corrected	Errors: 24
# read_20115 was corrected	Errors: 12
# read_20120 was corrected	Errors: 13
# read_20184 was corrected	Errors: 4
# read_20188 was corrected	Errors: 14
# read_20214 was corrected	Errors: 17
# read_20234 was corrected	Errors: 42
# read_20238 was corrected	Errors: 9
# read_20253 was corrected	Errors: 4
# read_20266 was corrected	Errors: 30
# read_20298 was corrected	Errors: 1
# read_20301 was corrected	Errors: 1
# read_20302 was corrected	Errors: 20
# read_20305 was corrected	Errors: 2
# read_20319 was corrected	Errors: 1
# read_20330 was corrected	Errors: 2
# read_20339 was corrected	Errors: 4
# read_20340 was corrected	Errors: 22
# read_20364 was corrected	Errors: 9
# read_20382 was corrected	Errors: 13
# read_20421 was corrected	Errors: 2
# read_20429 was corrected	Errors: 16
# read_20463 was corrected	Errors: 7
# read_20476 was corrected	Errors: 4
# read_20485 was corrected	Errors: 14
# read_20489 was corrected	Errors: 1
# read_20538 was corrected	Errors: 2
# read_20549 was corrected	Errors: 21
# read_20569 was corrected	Errors: 8
# read_20597 was corrected	Errors: 29
# read_20608 was corrected	Errors: 2
# read_20678 was corrected	Errors: 11
# read_20697 was corrected	Errors: 9
# read_20707 was corrected	Errors: 1
# read_20711 was corrected	Errors: 12
# read_20716 was corrected	Errors: 1
# read_20726 was corrected	Errors: 1
# read_20754 was corrected	Errors: 17
# read_20782 was corrected	Errors: 4
# read_20792 was corrected	Errors: 18
# read_20807 was corrected	Errors: 2
# read_20821 was corrected	Errors: 20
# read_20828 was corrected	Errors: 1
# read_20847 was corrected	Errors: 1
# read_20879 was corrected	Errors: 2
# read_20896 was corrected	Errors: 9
# read_20897 was corrected	Errors: 1
# read_20919 was corrected	Errors: 25
# read_20929 was corrected	Errors: 6
# read_20930 was corrected	Errors: 1
# read_20954 was corrected	Errors: 1
# read_20964 was corrected	Errors: 29
# read_20970 was corrected	Errors: 17
# read_20981 was corrected	Errors: 39
# read_20998 was corrected	Errors: 1
# read_21022 was corrected	Errors: 9
# read_21028 was corrected	Errors: 16
# read_21029 was corrected	Errors: 3
# read_21038 was corrected	Errors: 13
# read_21047 was corrected	Errors: 10
# read_21049 was corrected	Errors: 33
# read_21057 was corrected	Errors: 29
# read_21060 was corrected	Errors: 2
# read_21069 was corrected	Errors: 2
# read_21090 was corrected	Errors: 7
# read_21097 was corrected	Errors: 1
# read_21100 was corrected	Errors: 41
# read_21110 was corrected	Errors: 34
# read_21120 was corrected	Errors: 15
# read_21144 was corrected	Errors: 14
# read_21162 was corrected	Errors: 1
# read_21164 was corrected	Errors: 2
# read_21165 was corrected	Errors: 3
# read_21172 was corrected	Errors: 21
# read_21212 was corrected	Errors: 49
# read_21216 was corrected	Errors: 12
# read_21224 was corrected	Errors: 2
# read_21231 was corrected	Errors: 32
# read_21256 was corrected	Errors: 1
# read_21263 was corrected	Errors: 25
# read_21269 was corrected	Errors: 30
# read_21303 was corrected	Errors: 2
# read_21313 was corrected	Errors: 3
# read_21328 was corrected	Errors: 41
# read_21329 was corrected	Errors: 4
# read_21338 was corrected	Errors: 4
# read_21341 was corrected	Errors: 43
# read_21402 was corrected	Errors: 22
# read_21404 was corrected	Errors: 2
# read_21426 was corrected	Errors: 29
# read_21445 was corrected	Errors: 3
# read_21451 was corrected	Errors: 16
# read_21461 was corrected	Errors: 8
# read_21479 was corrected	Errors: 30
# read_21489 was corrected	Errors: 26
# read_21495 was corrected	Errors: 2
# read_21520 was corrected	Errors: 2
# read_21538 was corrected	Errors: 4
# read_21621 was corrected	Errors: 9
# read_21650 was corrected	Errors: 1
# read_21652 was corrected	Errors: 4
# read_21724 was corrected	Errors: 2
# read_21743 was corrected	Errors: 1
# read_21745 was corrected	Errors: 1
# read_21758 was corrected	Errors: 8
# read_21811 was corrected	Errors: 10
# read_21818 was corrected	Errors: 40
# read_21843 was corrected	Errors: 7
# read_21844 was corrected	Errors: 3
# read_21845 was corrected	Errors: 9
# read_21848 was corrected	Errors: 26
# read_21854 was corrected	Errors: 12
# read_21871 was corrected	Errors: 1
# read_21875 was corrected	Errors: 9
# read_21900 was corrected	Errors: 18
# read_21924 was corrected	Errors: 5
# read_21930 was corrected	Errors: 1
# read_21963 was corrected	Errors: 5
# read_21972 was corrected	Errors: 4
# read_21987 was corrected	Errors: 1
# read_21990 was corrected	Errors: 4
# read_21991 was corrected	Errors: 1
# read_22008 was corrected	Errors: 43
# read_22044 was corrected	Errors: 1
# read_22068 was corrected	Errors: 1
# read_22118 was corrected	Errors: 1
# read_22141 was corrected	Errors: 2
# read_22149 was corrected	Errors: 1
# read_22156 was corrected	Errors: 5
# read_22160 was corrected	Errors: 4
# read_22162 was corrected	Errors: 2
# read_22169 was corrected	Errors: 13
# read_22170 was corrected	Errors: 9
# read_22173 was corrected	Errors: 9
# read_22216 was corrected	Errors: 1
# read_22218 was corrected	Errors: 28
# read_22259 was corrected	Errors: 12
# read_22263 was corrected	Errors: 18
# read_22265 was corrected	Errors: 7
# read_22285 was corrected	Errors: 3
# read_22297 was corrected	Errors: 8
# read_22321 was corrected	Errors: 5
# read_22347 was corrected	Errors: 2
# read_22350 was corrected	Errors: 8
# read_22366 was corrected	Errors: 3
# read_22367 was corrected	Errors: 6
# read_22388 was corrected	Errors: 2
# read_22408 was corrected	Errors: 6
# read_22422 was corrected	Errors: 22
# read_22427 was corrected	Errors: 12
# read_22442 was corrected	Errors: 1
# read_22450 was corrected	Errors: 4
# read_22463 was corrected	Errors: 4
# read_22530 was corrected	Errors: 11
# read_22556 was corrected	Errors: 16
# read_22563 was corrected	Errors: 1
# read_22568 was corrected	Errors: 2
# read_22611 was corrected	Errors: 1
# read_22640 was corrected	Errors: 26
# read_22672 was corrected	Errors: 13
# read_22695 was corrected	Errors: 5
# read_22702 was corrected	Errors: 3
# read_22706 was corrected	Errors: 17
# read_22707 was corrected	Errors: 38
# read_22727 was corrected	Errors: 10
# read_22736 was corrected	Errors: 8
# read_22742 was corrected	Errors: 3
# read_22748 was corrected	Errors: 7
# read_22768 was corrected	Errors: 1
# read_22808 was corrected	Errors: 1
# read_22816 was corrected	Errors: 5
# read_22817 was corrected	Errors: 2
# read_22863 was corrected	Errors: 6
# read_22873 was corrected	Errors: 14
# read_22896 was corrected	Errors: 1
# read_22910 was corrected	Errors: 14
# read_22931 was corrected	Errors: 20
# read_22953 was corrected	Errors: 11
# read_22962 was corrected	Errors: 37
# read_22963 was corrected	Errors: 11
# read_22968 was corrected	Errors: 6
# read_22970 was corrected	Errors: 8
# read_22975 was corrected	Errors: 1
# read_22982 was corrected	Errors: 1
# read_22998 was corrected	Errors: 13
# read_23004 was corrected	Errors: 1
# read_23017 was corrected	Errors: 4
# read_23039 was corrected	Errors: 1
# read_23059 was corrected	Errors: 31
# read_23062 was corrected	Errors: 23
# read_23076 was corrected	Errors: 7
# read_23102 was corrected	Errors: 7
# read_23129 was corrected	Errors: 2
# read_23161 was corrected	Errors: 11
# read_23178 was corrected	Errors: 8
# read_23179 was corrected	Errors: 1
# read_23196 was corrected	Errors: 3
# read_23197 was corrected	Errors: 3
# read_23198 was corrected	Errors: 1
# read_23227 was corrected	Errors: 8
# read_23238 was corrected	Errors: 15
# read_23257 was corrected	Errors: 5
# read_23259 was corrected	Errors: 11
# read_23317 was corrected	Errors: 2
# read_23319 was corrected	Errors: 21
# read_23334 was corrected	Errors: 10
# read_23384 was corrected	Errors: 15
# read_23396 was corrected	Errors: 11
# read_23446 was corrected	Errors: 1
# read_23449 was corrected	Errors: 21
# read_23463 was corrected	Errors: 7
# read_23464 was corrected	Errors: 7
# read_23467 was corrected	Errors: 15
# read_23476 was corrected	Errors: 10
# read_23479 was corrected	Errors: 4
# read_23490 was corrected	Errors: 6
# read_23496 was corrected	Errors: 8
# read_23502 was corrected	Errors: 19
# read_23513 was corrected	Errors: 36
# read_23535 was corrected	Errors: 2
# read_23536 was corrected	Errors: 15
# read_23544 was corrected	Errors: 31
# read_23584 was corrected	Errors: 7
# read_23597 was corrected	Errors: 1
# read_23605 was corrected	Errors: 11
# read_23616 was corrected	Errors: 8
# read_23634 was corrected	Errors: 10
# read_23635 was corrected	Errors: 6
# read_23637 was corrected	Errors: 1
# read_23644 was corrected	Errors: 5
# read_23648 was corrected	Errors: 1
# read_23673 was corrected	Errors: 15
# read_23682 was corrected	Errors: 2
# read_23684 was corrected	Errors: 2
# read_23688 was corrected	Errors: 2
# read_23691 was corrected	Errors: 6
# read_23697 was corrected	Errors: 1
# read_23699 was corrected	Errors: 8
# read_23713 was corrected	Errors: 20
# read_23714 was corrected	Errors: 10
# read_23715 was corrected	Errors: 13
# read_23727 was corrected	Errors: 10
# read_23760 was corrected	Errors: 31
# read_23762 was corrected	Errors: 7
# read_23778 was corrected	Errors: 15
# read_23804 was corrected	Errors: 8
# read_23809 was corrected	Errors: 3
# read_23822 was corrected	Errors: 34
# read_23827 was corrected	Errors: 13
# read_23832 was corrected	Errors: 1
# read_23843 was corrected	Errors: 37
# read_23854 was corrected	Errors: 3
# read_23872 was corrected	Errors: 1
# read_23886 was corrected	Errors: 8
# read_23890 was corrected	Errors: 3
# read_23907 was corrected	Errors: 1
# read_23910 was corrected	Errors: 4
# read_23914 was corrected	Errors: 1
# read_23927 was corrected	Errors: 12
# read_23934 was corrected	Errors: 1
# read_23950 was corrected	Errors: 20
# read_23995 was corrected	Errors: 3
# read_24013 was corrected	Errors: 10
# read_24066 was corrected	Errors: 25
# read_24068 was corrected	Errors: 27
# read_24070 was corrected	Errors: 1
# read_24074 was corrected	Errors: 3
# read_24076 was corrected	Errors: 8
# read_24077 was corrected	Errors: 20
# read_24080 was corrected	Errors: 2
# read_24096 was corrected	Errors: 10
# read_24130 was corrected	Errors: 10
# read_24139 was corrected	Errors: 2
# read_24161 was corrected	Errors: 1
# read_24178 was corrected	Errors: 4
# read_24201 was corrected	Errors: 2
# read_24203 was corrected	Errors: 4
# read_24215 was corrected	Errors: 23
# read_24229 was corrected	Errors: 16
# ...
# read_41575 was corrected	Errors: 1
# read_41586 was corrected	Errors: 1
# read_41609 was corrected	Errors: 10
# read_41621 was corrected	Errors: 1
# read_41645 was corrected	Errors: 12
# read_41662 was corrected	Errors: 3
# read_41705 was corrected	Errors: 11
# read_41734 was corrected	Errors: 3
# read_41748 was corrected	Errors: 4
# read_41756 was corrected	Errors: 1
# read_41758 was corrected	Errors: 18
# read_41770 was corrected	Errors: 46
# read_41804 was corrected	Errors: 14
# read_41826 was corrected	Errors: 32
# read_41837 was corrected	Errors: 9
# read_41850 was corrected	Errors: 15
# read_41851 was corrected	Errors: 46
# read_41881 was corrected	Errors: 12
# read_41910 was corrected	Errors: 7
# read_41919 was corrected	Errors: 1
# read_41929 was corrected	Errors: 4
# read_41983 was corrected	Errors: 35
# read_42024 was corrected	Errors: 21
# read_42027 was corrected	Errors: 22
# read_42033 was corrected	Errors: 1
# read_42051 was corrected	Errors: 2
# read_42058 was corrected	Errors: 4
# read_42087 was corrected	Errors: 31
# read_42110 was corrected	Errors: 14
# read_42148 was corrected	Errors: 6
# read_42180 was corrected	Errors: 1
# read_42204 was corrected	Errors: 1
# read_42212 was corrected	Errors: 16
# read_42215 was corrected	Errors: 10
# read_42240 was corrected	Errors: 6
# read_42250 was corrected	Errors: 3
# read_42262 was corrected	Errors: 3
# read_42291 was corrected	Errors: 2
# read_42319 was corrected	Errors: 13
# read_42332 was corrected	Errors: 18
# read_42360 was corrected	Errors: 3
# read_42365 was corrected	Errors: 4
# read_42367 was corrected	Errors: 1
# read_42397 was corrected	Errors: 15
# read_42435 was corrected	Errors: 2
# read_42441 was corrected	Errors: 6
# read_42504 was corrected	Errors: 39
# read_42535 was corrected	Errors: 15
# read_42571 was corrected	Errors: 31
# read_42593 was corrected	Errors: 25
# read_42597 was corrected	Errors: 22
# read_42603 was corrected	Errors: 9
# read_42614 was corrected	Errors: 17
# read_42705 was corrected	Errors: 2
# read_42706 was corrected	Errors: 24
# read_42713 was corrected	Errors: 29
# read_42719 was corrected	Errors: 18
# read_42735 was corrected	Errors: 3
# read_42789 was corrected	Errors: 19
# read_42837 was corrected	Errors: 28
# read_42891 was corrected	Errors: 18
# read_42893 was corrected	Errors: 1
# read_42896 was corrected	Errors: 27
# read_42928 was corrected	Errors: 8
# read_42935 was corrected	Errors: 5
# read_42947 was corrected	Errors: 9
# read_42965 was corrected	Errors: 8
# read_42980 was corrected	Errors: 1
# read_42982 was corrected	Errors: 2
# read_42987 was corrected	Errors: 1
# read_42991 was corrected	Errors: 16
# read_43037 was corrected	Errors: 17
# read_43042 was corrected	Errors: 3
# read_43044 was corrected	Errors: 3
# read_43045 was corrected	Errors: 21
# read_43048 was corrected	Errors: 1
# read_43050 was corrected	Errors: 15
# read_43064 was corrected	Errors: 27
# read_43081 was corrected	Errors: 14
# read_43105 was corrected	Errors: 26
# read_43125 was corrected	Errors: 16
# read_43176 was corrected	Errors: 3
# read_43196 was corrected	Errors: 33
# read_43200 was corrected	Errors: 11
# read_43205 was corrected	Errors: 6
# read_43214 was corrected	Errors: 14
# read_43216 was corrected	Errors: 16
# read_43270 was corrected	Errors: 1
# read_43274 was corrected	Errors: 13
# read_43279 was corrected	Errors: 2
# read_43288 was corrected	Errors: 14
# read_43317 was corrected	Errors: 19
# read_43382 was corrected	Errors: 3
# read_43403 was corrected	Errors: 11
# read_43406 was corrected	Errors: 13
# read_43411 was corrected	Errors: 5
# read_43412 was corrected	Errors: 11
# read_43437 was corrected	Errors: 1
# read_43442 was corrected	Errors: 42
# read_43484 was corrected	Errors: 16
# read_43485 was corrected	Errors: 1
# read_43498 was corrected	Errors: 26
# read_43513 was corrected	Errors: 6
# read_43524 was corrected	Errors: 9
# read_43531 was corrected	Errors: 3
# read_43560 was corrected	Errors: 12
# read_43566 was corrected	Errors: 1
# read_43668 was corrected	Errors: 13
# read_43685 was corrected	Errors: 14
# read_43701 was corrected	Errors: 8
# read_43703 was corrected	Errors: 22
# read_43753 was corrected	Errors: 21
# read_43758 was corrected	Errors: 2
# read_43772 was corrected	Errors: 27
# read_43782 was corrected	Errors: 1
# read_43784 was corrected	Errors: 1
# read_43814 was corrected	Errors: 4
# read_43822 was corrected	Errors: 4
# read_43826 was corrected	Errors: 18
# read_43881 was corrected	Errors: 1
# read_43895 was corrected	Errors: 17
# read_43928 was corrected	Errors: 25
# read_43942 was corrected	Errors: 18
# read_43966 was corrected	Errors: 28
# read_43971 was corrected	Errors: 19
# read_43982 was corrected	Errors: 2
# read_44009 was corrected	Errors: 37
# read_44013 was corrected	Errors: 43
# read_44023 was corrected	Errors: 6
# read_44030 was corrected	Errors: 4
# read_44065 was corrected	Errors: 12
# read_44068 was corrected	Errors: 1
# read_44071 was corrected	Errors: 2
# read_44135 was corrected	Errors: 5
# read_44143 was corrected	Errors: 11
# read_44191 was corrected	Errors: 16
# read_44202 was corrected	Errors: 25
# read_44212 was corrected	Errors: 4
# read_44245 was corrected	Errors: 8
# read_44259 was corrected	Errors: 1
# read_44268 was corrected	Errors: 5
# read_44295 was corrected	Errors: 19
# read_44329 was corrected	Errors: 7
# read_44397 was corrected	Errors: 6
# read_44428 was corrected	Errors: 2
# read_44449 was corrected	Errors: 9
# read_44475 was corrected	Errors: 21
# read_44499 was corrected	Errors: 2
# read_44505 was corrected	Errors: 2
# read_44521 was corrected	Errors: 13
# read_44536 was corrected	Errors: 2
# read_44537 was corrected	Errors: 2
# read_44540 was corrected	Errors: 29
# read_44577 was corrected	Errors: 13
# read_44581 was corrected	Errors: 20
# read_44582 was corrected	Errors: 3
# read_44586 was corrected	Errors: 18
# read_44609 was corrected	Errors: 2
# read_44625 was corrected	Errors: 7
# read_44636 was corrected	Errors: 2
# read_44648 was corrected	Errors: 1
# read_44652 was corrected	Errors: 17
# read_44656 was corrected	Errors: 6
# read_44673 was corrected	Errors: 2
# read_44689 was corrected	Errors: 26
# read_44700 was corrected	Errors: 2
# read_44707 was corrected	Errors: 11
# read_44723 was corrected	Errors: 29
# read_44727 was corrected	Errors: 8
# read_44752 was corrected	Errors: 6
# read_44753 was corrected	Errors: 9
# read_44759 was corrected	Errors: 2
# read_44762 was corrected	Errors: 1
# read_44768 was corrected	Errors: 8
# read_44827 was corrected	Errors: 14
# read_44836 was corrected	Errors: 6
# read_44874 was corrected	Errors: 11
# read_44878 was corrected	Errors: 9
# read_44880 was corrected	Errors: 15
# read_44955 was corrected	Errors: 2
# read_44979 was corrected	Errors: 13
# read_44985 was corrected	Errors: 15
# read_44996 was corrected	Errors: 1
# read_44997 was corrected	Errors: 9
# read_45002 was corrected	Errors: 23
# read_45011 was corrected	Errors: 6
# read_45030 was corrected	Errors: 3
# read_45037 was corrected	Errors: 14
# read_45059 was corrected	Errors: 5
# read_45064 was corrected	Errors: 33
# read_45065 was corrected	Errors: 1
# read_45098 was corrected	Errors: 4
# read_45110 was corrected	Errors: 2
# read_45119 was corrected	Errors: 8
# read_45139 was corrected	Errors: 2
# read_45146 was corrected	Errors: 7
# read_45166 was corrected	Errors: 12
# read_45167 was corrected	Errors: 1
# read_45180 was corrected	Errors: 1
# read_45185 was corrected	Errors: 3
# read_45213 was corrected	Errors: 9
# read_45218 was corrected	Errors: 4
# read_45220 was corrected	Errors: 38
# read_45237 was corrected	Errors: 1
# read_45260 was corrected	Errors: 1
# read_45322 was corrected	Errors: 15
# read_45333 was corrected	Errors: 16
# read_45350 was corrected	Errors: 7
# read_45351 was corrected	Errors: 2
# read_45359 was corrected	Errors: 13
# read_45370 was corrected	Errors: 11
# read_45408 was corrected	Errors: 29
# read_45427 was corrected	Errors: 14
# read_45428 was corrected	Errors: 2
# read_45451 was corrected	Errors: 1
# read_45462 was corrected	Errors: 2
# read_45526 was corrected	Errors: 7
# read_45528 was corrected	Errors: 1
# read_45579 was corrected	Errors: 1
# read_45637 was corrected	Errors: 27
# read_45709 was corrected	Errors: 1
# read_45735 was corrected	Errors: 3
# read_45767 was corrected	Errors: 15
# read_45780 was corrected	Errors: 44
# read_45858 was corrected	Errors: 18
# read_45867 was corrected	Errors: 1
# read_45875 was corrected	Errors: 14
# read_45918 was corrected	Errors: 5
# read_45924 was corrected	Errors: 1
# read_45962 was corrected	Errors: 5
# read_45973 was corrected	Errors: 3
# read_45987 was corrected	Errors: 2
# read_46026 was corrected	Errors: 2
# read_46050 was corrected	Errors: 14
# read_46057 was corrected	Errors: 3
# read_46077 was corrected	Errors: 2
# read_46086 was corrected	Errors: 1
# read_46089 was corrected	Errors: 8
# read_46128 was corrected	Errors: 13
# read_46129 was corrected	Errors: 1
# read_46131 was corrected	Errors: 2
# read_46141 was corrected	Errors: 1
# read_46159 was corrected	Errors: 43
# read_46164 was corrected	Errors: 17
# read_46170 was corrected	Errors: 1
# read_46290 was corrected	Errors: 2
# read_46295 was corrected	Errors: 4
# read_46325 was corrected	Errors: 1
# read_46328 was corrected	Errors: 1
# read_46339 was corrected	Errors: 36
# read_46361 was corrected	Errors: 2
# read_46362 was corrected	Errors: 21
# read_46376 was corrected	Errors: 1
# read_46389 was corrected	Errors: 6
# read_46400 was corrected	Errors: 3
# read_46410 was corrected	Errors: 3
# read_46437 was corrected	Errors: 9
# read_46481 was corrected	Errors: 15
# read_46500 was corrected	Errors: 16
# read_46506 was corrected	Errors: 8
# read_46507 was corrected	Errors: 4
# read_46521 was corrected	Errors: 3
# read_46545 was corrected	Errors: 3
# read_46568 was corrected	Errors: 2
# read_46602 was corrected	Errors: 5
# read_46610 was corrected	Errors: 2
# read_46633 was corrected	Errors: 3
# read_46639 was corrected	Errors: 2
# read_46641 was corrected	Errors: 1
# read_46750 was corrected	Errors: 1
# read_46751 was corrected	Errors: 1
# read_46765 was corrected	Errors: 26
# read_46775 was corrected	Errors: 7
# read_46812 was corrected	Errors: 25
# read_46862 was corrected	Errors: 9
# read_46873 was corrected	Errors: 1
# read_46916 was corrected	Errors: 20
# read_46938 was corrected	Errors: 14
# read_46942 was corrected	Errors: 2
# read_46990 was corrected	Errors: 4
# read_47008 was corrected	Errors: 9
# read_47016 was corrected	Errors: 1
# read_47071 was corrected	Errors: 26
# read_47079 was corrected	Errors: 12
# read_47096 was corrected	Errors: 18
# read_47101 was corrected	Errors: 15
# read_47104 was corrected	Errors: 16
# read_47106 was corrected	Errors: 27
# read_47130 was corrected	Errors: 12
# read_47143 was corrected	Errors: 10
# read_47144 was corrected	Errors: 1
# read_47165 was corrected	Errors: 15
# read_47185 was corrected	Errors: 1
# read_47217 was corrected	Errors: 16
# read_47220 was corrected	Errors: 2
# read_47228 was corrected	Errors: 4
# read_47279 was corrected	Errors: 9
# read_47301 was corrected	Errors: 7
# read_47327 was corrected	Errors: 15
# read_47334 was corrected	Errors: 40
# read_47341 was corrected	Errors: 10
# read_47355 was corrected	Errors: 1
# read_47356 was corrected	Errors: 12
# read_47386 was corrected	Errors: 1
# read_47387 was corrected	Errors: 9
# read_47396 was corrected	Errors: 17
# read_47414 was corrected	Errors: 14
# read_47427 was corrected	Errors: 11
# read_47445 was corrected	Errors: 18
# read_47477 was corrected	Errors: 17
# read_47480 was corrected	Errors: 7
# read_47494 was corrected	Errors: 14
# read_47522 was corrected	Errors: 18
# read_47524 was corrected	Errors: 2
# read_47621 was corrected	Errors: 4
# read_47635 was corrected	Errors: 25
# read_47636 was corrected	Errors: 1
# read_47656 was corrected	Errors: 6
# read_47666 was corrected	Errors: 33
# read_47693 was corrected	Errors: 5
# read_47705 was corrected	Errors: 1
# read_47718 was corrected	Errors: 1
# read_47724 was corrected	Errors: 7
# read_47725 was corrected	Errors: 37
# read_47731 was corrected	Errors: 25
# read_47735 was corrected	Errors: 20
# read_47743 was corrected	Errors: 3
# read_47753 was corrected	Errors: 2
# read_47773 was corrected	Errors: 1
# read_47781 was corrected	Errors: 7
# read_47814 was corrected	Errors: 4
# read_47840 was corrected	Errors: 5
# read_47849 was corrected	Errors: 2
# read_47864 was corrected	Errors: 1
# read_47872 was corrected	Errors: 39
# read_47899 was corrected	Errors: 3
# read_47924 was corrected	Errors: 2
# read_47941 was corrected	Errors: 12
# read_47945 was corrected	Errors: 3
# read_47964 was corrected	Errors: 7
# read_47965 was corrected	Errors: 13
# read_48004 was corrected	Errors: 2
# read_48029 was corrected	Errors: 4
# read_48082 was corrected	Errors: 18
# read_48119 was corrected	Errors: 34
# read_48127 was corrected	Errors: 6
# read_48163 was corrected	Errors: 13
# read_48200 was corrected	Errors: 1
# read_48201 was corrected	Errors: 2
# read_48209 was corrected	Errors: 9
# read_48246 was corrected	Errors: 8
# read_48261 was corrected	Errors: 9
# read_48296 was corrected	Errors: 17
# read_48340 was corrected	Errors: 3
# read_48347 was corrected	Errors: 12
# read_48350 was corrected	Errors: 18
# read_48356 was corrected	Errors: 28
# read_48403 was corrected	Errors: 16
# read_48405 was corrected	Errors: 1
# read_48437 was corrected	Errors: 3
# read_48447 was corrected	Errors: 10
# read_48479 was corrected	Errors: 1
# read_48515 was corrected	Errors: 15
# read_48522 was corrected	Errors: 20
# read_48528 was corrected	Errors: 8
# read_48544 was corrected	Errors: 32
# read_48608 was corrected	Errors: 29
# read_48633 was corrected	Errors: 4
# read_48669 was corrected	Errors: 2
# read_48676 was corrected	Errors: 1
# read_48678 was corrected	Errors: 37
# read_48684 was corrected	Errors: 15
# read_48721 was corrected	Errors: 19
# read_48723 was corrected	Errors: 2
# read_48736 was corrected	Errors: 2
# read_48740 was corrected	Errors: 19
# read_48774 was corrected	Errors: 1
# read_48775 was corrected	Errors: 8
# read_48779 was corrected	Errors: 2
# read_48807 was corrected	Errors: 2
# read_48830 was corrected	Errors: 12
# read_48861 was corrected	Errors: 9
# read_48864 was corrected	Errors: 11
# read_48866 was corrected	Errors: 19
# read_48869 was corrected	Errors: 1
# read_48876 was corrected	Errors: 13
# read_48915 was corrected	Errors: 1
# read_48926 was corrected	Errors: 14
# read_48928 was corrected	Errors: 33
# read_48934 was corrected	Errors: 28
# read_48948 was corrected	Errors: 18
# read_48950 was corrected	Errors: 1
# read_48953 was corrected	Errors: 8
# read_48965 was corrected	Errors: 10
# read_48980 was corrected	Errors: 1
# read_48998 was corrected	Errors: 3
# read_49013 was corrected	Errors: 3
# read_49027 was corrected	Errors: 1
# read_49066 was corrected	Errors: 5
# read_49081 was corrected	Errors: 8
# read_49097 was corrected	Errors: 1
# read_49104 was corrected	Errors: 4
# read_49150 was corrected	Errors: 28
# read_49166 was corrected	Errors: 19
# read_49174 was corrected	Errors: 3
# read_49176 was corrected	Errors: 45
# read_49213 was corrected	Errors: 8
# read_49216 was corrected	Errors: 7
# read_49267 was corrected	Errors: 5
# read_49283 was corrected	Errors: 17
# read_49284 was corrected	Errors: 21
# read_49297 was corrected	Errors: 1
# read_49307 was corrected	Errors: 6
# read_49310 was corrected	Errors: 18
# read_49315 was corrected	Errors: 4
# read_49362 was corrected	Errors: 7
# read_49363 was corrected	Errors: 4
# read_49393 was corrected	Errors: 1
# read_49426 was corrected	Errors: 4
# read_49438 was corrected	Errors: 1
# read_49462 was corrected	Errors: 2
# read_49475 was corrected	Errors: 20
# read_49517 was corrected	Errors: 1
# read_49535 was corrected	Errors: 2
# read_49543 was corrected	Errors: 3
# read_49546 was corrected	Errors: 4
# read_49555 was corrected	Errors: 1
# read_49561 was corrected	Errors: 1
# read_49565 was corrected	Errors: 18
# read_49583 was corrected	Errors: 4
# read_49675 was corrected	Errors: 1
# read_49690 was corrected	Errors: 21
# read_49691 was corrected	Errors: 2
# read_49692 was corrected	Errors: 4
# read_49730 was corrected	Errors: 5
# read_49742 was corrected	Errors: 5
# read_49797 was corrected	Errors: 1
# read_49808 was corrected	Errors: 5
# read_49825 was corrected	Errors: 4
# read_49832 was corrected	Errors: 3
# read_49835 was corrected	Errors: 9
# read_49847 was corrected	Errors: 7
# read_49858 was corrected	Errors: 1
# read_49871 was corrected	Errors: 5
# read_49884 was corrected	Errors: 3
# read_49899 was corrected	Errors: 32
# read_49921 was corrected	Errors: 15
# read_49922 was corrected	Errors: 8
# read_49960 was corrected	Errors: 2
# read_49981 was corrected	Errors: 25
# read_49994 was corrected	Errors: 29

# %%
# Проверка на количество измененных ридов
print(f"{racer_count}/50.000 were corrected\nMatch rate is {round(100*racer_count/50000, 3)}%")
# Out:
# 2753/50.000 were corrected
# Match rate is 5.506%

# %% [markdown]
# Данный тул уже вносит изменения

# %% [markdown]
# [link](https://neerc.ifmo.ru/wiki/index.php?title=%D0%9E%D1%86%D0%B5%D0%BD%D0%BA%D0%B0_%D0%BA%D0%B0%D1%87%D0%B5%D1%81%D1%82%D0%B2%D0%B0_%D0%B2_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%D0%B0%D1%85_%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D0%B8#:~:text=FP%20%E2%80%94%20false%20positive%3A%20%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%82%D0%BE%D1%80%20%D0%BD%D0%B5%D0%B2%D0%B5%D1%80%D0%BD%D0%BE,%D0%BD%D0%B5%20%D0%BF%D1%80%D0%B8%D0%BD%D0%B0%D0%B4%D0%BB%D0%B5%D0%B6%D0%B8%D1%82%20%D0%BA%20%D1%80%D0%B0%D1%81%D1%81%D0%BC%D0%B0%D1%82%D1%80%D0%B8%D0%B2%D0%B0%D0%B5%D0%BC%D0%BE%D0%BC%D1%83%20%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D1%83.)
#
#
# * TP — true positive: классификатор верно отнёс объект к рассматриваемому классу.
# * TN — true negative: классификатор верно утверждает, что объект не принадлежит к рассматриваемому классу.
# * FP — false positive: классификатор неверно отнёс объект к рассматриваемому классу.
# * FN — false negative: классификатор неверно утверждает, что объект не принадлежит к рассматриваемому классу.

# %% [markdown]
# рассматриваемый класс - нуклеотид в правильном риде
# * TP - после работы тула нуклеотид такой же как в оригинальном риде
# * TN - иллюмина была с ошибкой. Тул увидел, попробовал исправить, но неудачно
#
# * FP -
# * FN - ???

# %% [markdown]
# Не могу сформулировать, что в данном случае понимать за fp, fn, поэтому буду отталкиваться от следующей матрицы ошибок
#
# | Геном (факт) \ Предсказание тула | Предсказано изменение относительно illumina | Не предсказано |
# | --- | --- | --- |
# | Совпадает | TP | FP |
# | НЕсовпадает | FN | TN |

# %%
def check_rate(file2, true_reads=true_reads):
    """сравнивает fastq файл с корректными ридами и считает метрики TP, TN, FP, FN"""
    
    file1 = "simulated_reads.fastq"
    reads1 = read_fastq(file1)
    reads2 = read_fastq(file2)
    
    TP, TN, FP, FN = 0, 0, 0, 0

    count = 0
    for true_seq, read1, read2 in zip(true_reads, reads1, reads2):
        illumina_seq = read1["seq"]
        corrected_seq = read2["seq"]
        for t, i, c in zip(true_seq, illumina_seq, corrected_seq):
            count += 1

            if c != i:
                if t == c:
                    TP += 1
                else:
                    FN += 1   
            elif c == i:
                if c == t:
                    TP += 1
                else:
                    FN += 1
                

    assert count == TP + TN + FP + FN
    procent = lambda x: str(round(x, 3)) + "%"

    print(f"TP = {TP}\t or {procent(100*TP/count)}")
    print(f"TN = {TN}\t or {procent(100*TN/count)}")
    print(f"FP = {FP}\t or {procent(100*FP/count)}")
    print(f"FN = {FN}\t or {procent(100*FN/count)}")

# %%
# метрики по 3 заданию
# сравнение по всем нуклеотидам
check_rate("racer.fastq")
# Out:
# TP = 11183255	 or 89.638%
# TN = 0	 or 0.0%
# FP = 0	 or 0.0%
# FN = 1292822	 or 10.362%

# %% [markdown]
# ## 4
#
# Racer сделал множество сомнительных исправлений, по отработал быстрее
#
#
# На графиках в исходной статье он находится отдельно от остальных инструментов, работая существенно быстрее при меньшей точности - здесь, в целом, поведение такое же как в статье
